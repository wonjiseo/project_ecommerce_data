# %%
import pandas

# %%
data=pandas.read_csv('Search2.csv')

# %%
data.head(100)
# Out:
#      SESS_DT      KWD_NM SEARCH_CNT
# 0   20180407       닥스원피스          8
# 1   20180407   닥터지 브라이트닝          1
# 2   20180407      달팡 인트랄          2
# 3   20180407         대상트          1
# 4   20180407        더블유닷          6
# 5   20180407   더블하트 모유실감          1
# 6   20180407    데님 롱 스커트          6
# 7   20180407      데상트 크론         12
# 8   20180407     데상트골프여성          6
# 9   20180407     데상트여성골프          1
# 10  20180407    데상트여성티셔츠          2
# 11  20180407       데코뷰커튼          4
# 12  20180407         덴탈껌          1
# 13  20180407      도깨비방망이          8
# 14  20180407        도마꽂이          6
# 15  20180407        동물잠옷         31
# 16  20180407     동서가구 쇼파          1
# 17  20180407         돼지코          1
# 18  20180407          드넬          4
# 19  20180407        드마리스          3
# 20  20180407        등산조끼         10
# 21  20180407      디데무티셔츠          9
# 22  20180407    디스커버리 남성         24
# 23  20180407  디스커버리 스니커즈          3
# 24  20180407   디스커버리남성패딩          4
# ...

# %%
data.shape
# Out:
# (8051172, 3)

# %%
len(data['KWD_NM'].unique())
# Out:
# 84607

# %%
counts=data['KWD_NM'].value_counts().to_frame()

# %%
counts.head
# Out:
# <bound method NDFrame.head of                 KWD_NM
# 아기옷                183
# 로레알                183
# 나이스클랍              183
# system             183
# 빈폴 가방              183
# 덱케                 183
# 헤지스레이디스 원피스        183
# 조말론향수              183
# 제이에스티나 반지          183
# 접시                 183
# 여성 로퍼              183
# 투미 크로스백            183
# soup               183
# 캉골 에코백             183
# 간식                 183
# 듀퐁                 183
# 과자                 183
# 도시락                183
# 커스텀멜로우             183
# 나이키 여성 티셔츠         183
# 지오다노 여성            183
# 에꼴                 183
# 스탠스미스              183
# 엣코너                183
# 노스페이스화이트라벨         183
# 아이키커               183
# 행텐                 183
# 라코스테 가방            183
# 라코스테 신발            183
# 4CUS               183
# ...                ...
# 닥스맨반팔셔츠              6
# 에이치커넥트남성반팔티          6
# 519611746            5
# yj8fbs107            5
# 플레이키즈프로 나이키 모자       5
# DOLCE                5
# ...

# %%
searchname=data['KWD_NM']

# %%
searchname
# Out:
# 0                    닥스원피스
# 1                닥터지 브라이트닝
# 2                   달팡 인트랄
# 3                      대상트
# 4                     더블유닷
# 5                더블하트 모유실감
# 6                 데님 롱 스커트
# 7                   데상트 크론
# 8                  데상트골프여성
# 9                  데상트여성골프
# 10                데상트여성티셔츠
# 11                   데코뷰커튼
# 12                     덴탈껌
# 13                  도깨비방망이
# 14                    도마꽂이
# 15                    동물잠옷
# 16                 동서가구 쇼파
# 17                     돼지코
# 18                      드넬
# 19                    드마리스
# 20                    등산조끼
# 21                  디데무티셔츠
# 22                디스커버리 남성
# 23              디스커버리 스니커즈
# 24               디스커버리남성패딩
# 25                 딥디크 탐다오
# 26                    따블리에
# 27                 땡땡이 스커트
# 28                  라글란티셔츠
# 29              라코스테 여성 셔츠
#                 ...
# 8051142               OHUI
# 8051143              OPI네일
# 8051144                PS4
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-30-d5396d55ca21> in <module>
#       1 for i in range(0,8051172):
#       2     if searchname[i].isdigit()==True:
# ----> 3         data.drop(['i'])
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3778         for axis, labels in axes.items():
#    3779             if labels is not None:
# ...

# %%
data(3780,)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-f1f1ece9dfdc> in <module>
# ----> 1 data(3780,)
#
# TypeError: 'DataFrame' object is not callable

# %%
data.shape
# Out:
# (8051172, 3)

# %%
data.info
# Out:
# <bound method DataFrame.info of           SESS_DT           KWD_NM SEARCH_CNT
# 0        20180407            닥스원피스          8
# 1        20180407        닥터지 브라이트닝          1
# 2        20180407           달팡 인트랄          2
# 3        20180407              대상트          1
# 4        20180407             더블유닷          6
# 5        20180407        더블하트 모유실감          1
# 6        20180407         데님 롱 스커트          6
# 7        20180407           데상트 크론         12
# 8        20180407          데상트골프여성          6
# 9        20180407          데상트여성골프          1
# 10       20180407         데상트여성티셔츠          2
# 11       20180407            데코뷰커튼          4
# 12       20180407              덴탈껌          1
# 13       20180407           도깨비방망이          8
# 14       20180407             도마꽂이          6
# 15       20180407             동물잠옷         31
# 16       20180407          동서가구 쇼파          1
# 17       20180407              돼지코          1
# 18       20180407               드넬          4
# ...

# %%
data.describe
# Out:
# <bound method NDFrame.describe of           SESS_DT           KWD_NM SEARCH_CNT
# 0        20180407            닥스원피스          8
# 1        20180407        닥터지 브라이트닝          1
# 2        20180407           달팡 인트랄          2
# 3        20180407              대상트          1
# 4        20180407             더블유닷          6
# 5        20180407        더블하트 모유실감          1
# 6        20180407         데님 롱 스커트          6
# 7        20180407           데상트 크론         12
# 8        20180407          데상트골프여성          6
# 9        20180407          데상트여성골프          1
# 10       20180407         데상트여성티셔츠          2
# 11       20180407            데코뷰커튼          4
# 12       20180407              덴탈껌          1
# 13       20180407           도깨비방망이          8
# 14       20180407             도마꽂이          6
# 15       20180407             동물잠옷         31
# 16       20180407          동서가구 쇼파          1
# 17       20180407              돼지코          1
# 18       20180407               드넬          4
# ...

# %%
counts=data['KWD_NM'].value_counts()

# %%
counts.
# Out:
# 아기옷               183
# 로레알               183
# 나이스클랍             183
# system            183
# 빈폴 가방             183
# 덱케                183
# 헤지스레이디스 원피스       183
# 조말론향수             183
# 제이에스티나 반지         183
# 접시                183
# 여성 로퍼             183
# 투미 크로스백           183
# soup              183
# 캉골 에코백            183
# 간식                183
# 듀퐁                183
# 과자                183
# 도시락               183
# 커스텀멜로우            183
# 나이키 여성 티셔츠        183
# 지오다노 여성           183
# 에꼴                183
# 스탠스미스             183
# 엣코너               183
# 노스페이스화이트라벨        183
# 아이키커              183
# 행텐                183
# 라코스테 가방           183
# 라코스테 신발           183
# 4CUS              183
#                  ...
# 닥스맨반팔셔츠             6
# 에이치커넥트남성반팔티         6
# 519611746           5
# yj8fbs107           5
# 플레이키즈프로 나이키 모자      5
# DOLCE               5
# 508551136           5
# 디아도라 분당점            4
# 라운드카라 자켓            4
# jelispoon           4
# ...

# %%
counts_data=counts.drop('실패검색',axis=0)

# %%
counts_data.head(100)
# Out:
# 아기옷             183
# 로레알             183
# 나이스클랍           183
# system          183
# 빈폴 가방           183
# 덱케              183
# 헤지스레이디스 원피스     183
# 조말론향수           183
# 제이에스티나 반지       183
# 접시              183
# 여성 로퍼           183
# 투미 크로스백         183
# soup            183
# 캉골 에코백          183
# 간식              183
# 듀퐁              183
# 과자              183
# 도시락             183
# 커스텀멜로우          183
# 나이키 여성 티셔츠      183
# 지오다노 여성         183
# 에꼴              183
# 스탠스미스           183
# 엣코너             183
# 노스페이스화이트라벨      183
# 아이키커            183
# 행텐              183
# 라코스테 가방         183
# 라코스테 신발         183
# 4CUS            183
#                ...
# 라코스테 여성         183
# 쿠론 클러치          183
# 롱치마             183
# 홍이장군2단계         183
# 커피잔             183
# 루즈핏 티셔츠         183
# 빈폴레이디스 셔츠       183
# 에프알제이           183
# 마이클코어스가방        183
# 네스프레소 캡슐        183
# 남성 스니커즈         183
# 헤지스 남성 티셔츠      183
# 코데즈 컴바인 남성속옷    183
# 트리아나            183
# ...

# %%
counts_sort=counts_data.sort_values(ascending=True)

# %%
counts_sort.head(100)
# Out:
# 첨이첨이아동양면내복          1
# 페이스 프라이머            1
# 롤러 래시               1
# 클라이드 광주점            1
# daks kids           1
# silicone            1
# 미니 사이즈              2
# 핑크 블러셔              2
# sooryehan           2
# andi apple          2
# 에이지투웨니스 한정판         3
# Benefit             3
# 535280485           3
# 독일 명품 세라믹           3
# 카-브로우               3
# ZIOZIA              3
# bestibelli          3
# 디아도라 분당점            4
# 왓츠 업                4
# jelispoon           4
# 라운드카라 자켓            4
# 508551136           5
# DOLCE               5
# 플레이키즈프로 나이키 모자      5
# 519611746           5
# 미미네 아쿠아             6
# parklon             6
# 널디트레이닝복             6
# 꼬꼬댁 꼬꼬              6
# 닥스맨반팔셔츠             6
#                    ..
# 위니아제습기18           10
# 빈폴레이디스 큐롯 스커트팬츠    10
# 남성 등산 반팔티          10
# 여성7부 티             10
# 소니 55mm            10
# 남성 등산점퍼            10
# 반에이크청량리            11
# design united      11
# 자연미인가구 타임          11
# 고프로7               11
# ...

# %%
counts_data=counts_data.drop('22주년 축하해',axis=0)

# %%
counts_data
# Out:
# 아기옷               183
# 로레알               183
# 나이스클랍             183
# system            183
# 빈폴 가방             183
# 덱케                183
# 헤지스레이디스 원피스       183
# 조말론향수             183
# 제이에스티나 반지         183
# 접시                183
# 여성 로퍼             183
# 투미 크로스백           183
# soup              183
# 캉골 에코백            183
# 간식                183
# 듀퐁                183
# 과자                183
# 도시락               183
# 커스텀멜로우            183
# 나이키 여성 티셔츠        183
# 지오다노 여성           183
# 에꼴                183
# 스탠스미스             183
# 엣코너               183
# 노스페이스화이트라벨        183
# 아이키커              183
# 행텐                183
# 라코스테 가방           183
# 라코스테 신발           183
# 4CUS              183
#                  ...
# T.I FOR MEN         6
# [아메리칸이글(진)]남성       6
# 닥스맨반팔셔츠             6
# 에이치커넥트남성반팔티         6
# 519611746           5
# 플레이키즈프로 나이키 모자      5
# DOLCE               5
# 508551136           5
# 디아도라 분당점            4
# 라운드카라 자켓            4
# ...

# %%
counts_data=counts_data.drop('인터넷방송',axis=0)

# %%
counts_data
# Out:
# 아기옷               183
# 로레알               183
# 나이스클랍             183
# system            183
# 빈폴 가방             183
# 덱케                183
# 헤지스레이디스 원피스       183
# 조말론향수             183
# 제이에스티나 반지         183
# 접시                183
# 여성 로퍼             183
# 투미 크로스백           183
# soup              183
# 캉골 에코백            183
# 간식                183
# 듀퐁                183
# 과자                183
# 도시락               183
# 커스텀멜로우            183
# 나이키 여성 티셔츠        183
# 지오다노 여성           183
# 에꼴                183
# 스탠스미스             183
# 엣코너               183
# 노스페이스화이트라벨        183
# 아이키커              183
# 행텐                183
# 라코스테 가방           183
# 라코스테 신발           183
# 4CUS              183
#                  ...
# 첨이첨이남아7부내의          6
# T.I FOR MEN         6
# [아메리칸이글(진)]남성       6
# 닥스맨반팔셔츠             6
# 에이치커넥트남성반팔티         6
# 519611746           5
# 플레이키즈프로 나이키 모자      5
# DOLCE               5
# 508551136           5
# 디아도라 분당점            4
# ...

# %%
counts_data=counts_data.drop('2wms',axis=0)

# %%
cou
